# %%
# SETUP

import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt

db_path = 'sp.csv'
plot_path = 'plt.pdf'
# db_path = input("Caminho para .csv:\n -> ")
# plot_path = input("\n\n plot output path:\n -> ")

df = pd.read_csv(db_path, sep=';')

#filtrando internações SUP_MEDIA
#consequente = df[(df.internacao=='inf_media') | (df.internacao=='superior_media') ]
consequente = df[df['internacao'] != 'inf_media'].dropna()
consequente = consequente.reset_index(drop=True)
consequente
# Out:
#            Data       MP25       MP10         CO        SO2        NO2  \
# 0    01/02/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 1    13/02/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 2    14/02/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 3    15/02/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 4    16/02/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# ..          ...        ...        ...        ...        ...        ...
# 826  05/10/2021  inf_media  inf_media  inf_media  inf_media  inf_media
# 827  06/10/2021  inf_media  inf_media  inf_media  inf_media  inf_media
# 828  07/10/2021  inf_media  inf_media  inf_media  inf_media  inf_media
# 829  14/10/2021  inf_media  inf_media  inf_media  inf_media  inf_media
# 830  15/10/2021  inf_media  inf_media  inf_media  inf_media  inf_media
#
#             O3 internacao
# 0    inf_media  sup_media
# 1    inf_media  sup_media
# 2    inf_media  sup_media
# 3    sup_media  sup_media
# 4    sup_media  sup_media
# ..         ...        ...
# 826  inf_media  sup_media
# 827  inf_media  sup_media
# 828  inf_media  sup_media
# 829  inf_media  sup_media
# 830  inf_media  sup_media
#
# [831 rows x 8 columns]

# %%
#filtrando poluentes SUP_MEDIA
inter_filter = consequente[(consequente.MP25=='sup_media') | (consequente.MP10=='sup_media') | (consequente.CO=='sup_media') | (consequente.SO2=='sup_media') | (consequente.NO2=='sup_media') | (consequente.O3=='sup_media')]
inter_filter = inter_filter.reset_index(drop=True)
inter_filter
# Out:
#            Data       MP25       MP10         CO        SO2        NO2  \
# 0    15/02/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 1    16/02/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 2    17/02/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 3    18/02/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 4    21/02/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# ..          ...        ...        ...        ...        ...        ...
# 298  21/09/2021  sup_media  sup_media  inf_media  inf_media  inf_media
# 299  22/09/2021  sup_media  sup_media  inf_media  inf_media  inf_media
# 300  27/09/2021  sup_media  sup_media  inf_media  inf_media  inf_media
# 301  28/09/2021  sup_media  sup_media  inf_media  inf_media  inf_media
# 302  29/09/2021  sup_media  sup_media  inf_media  inf_media  inf_media
#
#             O3 internacao
# 0    sup_media  sup_media
# 1    sup_media  sup_media
# 2    sup_media  sup_media
# 3    sup_media  sup_media
# 4    sup_media  sup_media
# ..         ...        ...
# 298  inf_media  sup_media
# 299  inf_media  sup_media
# 300  sup_media  sup_media
# 301  sup_media  sup_media
# 302  sup_media  sup_media
#
# [303 rows x 8 columns]

# %%
# resumo
inter_filter.describe()
# Out:
#               Data       MP25       MP10         CO        SO2        NO2  \
# count          303        303        303        303        303        303
# unique         303          2          2          1          1          1
# top     15/02/2017  sup_media  sup_media  inf_media  inf_media  inf_media
# freq             1        259        174        303        303        303
#
#                O3 internacao
# count         303        303
# unique          2          1
# top     inf_media  sup_media
# freq          223        303

# %%
# DETECÇÃO DE PADRÕES

db = {}  # irá armazenar os padrões em dias consecutivos
code = 0 # chave de acesso ao db
for index, row_i in inter_filter.iterrows():
    if index == 0:
        row_0 = row_i

    # salve os tempos iniciais e finais (b e f) do padrão
    b = datetime.datetime.strptime(row_0['Data'], '%d/%m/%Y')    
    f = datetime.datetime.strptime(row_i['Data'], '%d/%m/%Y')
    diff = (f - b).days
    
    # padrão que não se repete em dias consecutivos
    pattern = [
        datetime.datetime.strftime(f, '%d/%m/%y'),
        datetime.datetime.strftime(f, '%d/%m/%y'),
        *row_i[1:]
    ]    
    
    # padrão que se repete em dias consecutivos
    if (row_i[1:].equals(row_0[1:])) and diff <= 1:
                    
        pattern = [
            datetime.datetime.strftime(b, '%d/%m/%y'),
            datetime.datetime.strftime(f, '%d/%m/%y'),
            *row_i[1:]
        ]
    else:
        code += 1
        
    # guarde o padrão no novo db
    if db.get(code, 0):
        db[code][1] = pattern[1] # apenas altera a data f caso já exista
    else:
        db[code] = pattern
    
    # passo
    row_0 = row_i

# %%
# lista os padrões com os tempos iniciais e finais (b e f)
db
# Out:
# {0: ['15/02/17',
#   '18/02/17',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  1: ['21/02/17',
#   '21/02/17',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  2: ['23/02/17',
#   '23/02/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  3: ['10/03/17',
#   '10/03/17',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  4: ['17/03/17',
#   '17/03/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  5: ['25/03/17',
#   '25/03/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  6: ['05/04/17',
#   '05/04/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  7: ['15/04/17',
#   '15/04/17',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  8: ['03/05/17',
#   '05/05/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  9: ['09/05/17',
#   '09/05/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  10: ['25/05/17',
#   '25/05/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  11: ['29/05/17',
#   '29/05/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  12: ['08/06/17',
#   '08/06/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  13: ['12/06/17',
#   '14/06/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  14: ['17/06/17',
#   '17/06/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  15: ['19/06/17',
#   '19/06/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  16: ['28/06/17',
#   '29/06/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  17: ['30/06/17',
#   '01/07/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  18: ['11/07/17',
#   '13/07/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  19: ['14/07/17',
#   '14/07/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  20: ['21/07/17',
#   '21/07/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  21: ['01/08/17',
#   '03/08/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  22: ['07/08/17',
#   '07/08/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  23: ['08/08/17',
#   '10/08/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  24: ['14/08/17',
#   '14/08/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  25: ['24/08/17',
#   '24/08/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  26: ['30/08/17',
#   '30/08/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  27: ['31/08/17',
#   '31/08/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  28: ['04/09/17',
#   '04/09/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  29: ['05/09/17',
#   '06/09/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  30: ['11/09/17',
#   '13/09/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  31: ['14/09/17',
#   '14/09/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  32: ['15/09/17',
#   '15/09/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  33: ['18/09/17',
#   '20/09/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  34: ['21/09/17',
#   '22/09/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  35: ['26/09/17',
#   '26/09/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  36: ['28/09/17',
#   '28/09/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  37: ['06/10/17',
#   '06/10/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  38: ['09/10/17',
#   '11/10/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  39: ['19/10/17',
#   '19/10/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  40: ['20/10/17',
#   '20/10/17',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  41: ['09/11/17',
#   '10/11/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  42: ['16/11/17',
#   '16/11/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  43: ['04/12/17',
#   '04/12/17',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  44: ['05/12/17',
#   '05/12/17',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  45: ['14/12/17',
#   '14/12/17',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  46: ['01/03/18',
#   '01/03/18',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  47: ['19/03/18',
#   '19/03/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  48: ['20/03/18',
#   '20/03/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  49: ['23/03/18',
#   '23/03/18',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  50: ['13/04/18',
#   '13/04/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  51: ['20/04/18',
#   '20/04/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  52: ['21/04/18',
#   '21/04/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  53: ['23/04/18',
#   '26/04/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  54: ['01/05/18',
#   '01/05/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  55: ['02/05/18',
#   '02/05/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  56: ['04/05/18',
#   '04/05/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  57: ['11/05/18',
#   '12/05/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  58: ['16/05/18',
#   '16/05/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  59: ['22/05/18',
#   '22/05/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  60: ['23/05/18',
#   '23/05/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  61: ['24/05/18',
#   '24/05/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  62: ['01/06/18',
#   '03/06/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  63: ['06/06/18',
#   '07/06/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  64: ['12/06/18',
#   '12/06/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  65: ['21/06/18',
#   '21/06/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  66: ['25/06/18',
#   '29/06/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  67: ['01/07/18',
#   '01/07/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  68: ['02/07/18',
#   '05/07/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  69: ['07/07/18',
#   '07/07/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  70: ['09/07/18',
#   '09/07/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  71: ['13/07/18',
#   '13/07/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  72: ['16/07/18',
#   '17/07/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  73: ['19/07/18',
#   '19/07/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  74: ['15/08/18',
#   '15/08/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  75: ['20/08/18',
#   '20/08/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  76: ['21/08/18',
#   '21/08/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  77: ['22/08/18',
#   '22/08/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  78: ['23/08/18',
#   '24/08/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  79: ['03/09/18',
#   '03/09/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  80: ['10/09/18',
#   '10/09/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  81: ['14/09/18',
#   '14/09/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  82: ['24/09/18',
#   '24/09/18',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  83: ['25/09/18',
#   '25/09/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  84: ['26/09/18',
#   '27/09/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  85: ['02/10/18',
#   '04/10/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  86: ['02/11/18',
#   '02/11/18',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  87: ['05/12/18',
#   '05/12/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  88: ['26/03/19',
#   '26/03/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  89: ['03/04/19',
#   '03/04/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  90: ['04/04/19',
#   '04/04/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  91: ['05/04/19',
#   '06/04/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  92: ['13/04/19',
#   '13/04/19',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  93: ['19/04/19',
#   '19/04/19',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  94: ['22/04/19',
#   '22/04/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  95: ['23/04/19',
#   '23/04/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  96: ['02/05/19',
#   '05/05/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  97: ['06/05/19',
#   '06/05/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  98: ['22/05/19',
#   '23/05/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  99: ['28/05/19',
#   '28/05/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  100: ['08/06/19',
#   '08/06/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  101: ['10/06/19',
#   '10/06/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  102: ['11/06/19',
#   '14/06/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  103: ['15/06/19',
#   '18/06/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  104: ['19/06/19',
#   '20/06/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  105: ['24/06/19',
#   '24/06/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  106: ['25/06/19',
#   '26/06/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  107: ['27/06/19',
#   '27/06/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  108: ['01/07/19',
#   '01/07/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  109: ['02/07/19',
#   '04/07/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  110: ['11/07/19',
#   '11/07/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  111: ['15/07/19',
#   '15/07/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  112: ['16/07/19',
#   '16/07/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  113: ['25/07/19',
#   '25/07/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  114: ['01/08/19',
#   '01/08/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  115: ['08/08/19',
#   '08/08/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  116: ['09/08/19',
#   '09/08/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  117: ['12/08/19',
#   '13/08/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  118: ['14/08/19',
#   '14/08/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  119: ['01/09/19',
#   '01/09/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  120: ['09/09/19',
#   '09/09/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  121: ['10/09/19',
#   '10/09/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  122: ['11/09/19',
#   '11/09/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  123: ['12/09/19',
#   '12/09/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  124: ['16/09/19',
#   '16/09/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  125: ['17/09/19',
#   '18/09/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  126: ['19/09/19',
#   '20/09/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  127: ['01/10/19',
#   '01/10/19',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  128: ['02/10/19',
#   '02/10/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  129: ['03/10/19',
#   '03/10/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  130: ['04/10/19',
#   '04/10/19',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  131: ['05/10/19',
#   '05/10/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  132: ['14/10/19',
#   '14/10/19',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  133: ['18/10/19',
#   '18/10/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  134: ['22/10/19',
#   '22/10/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  135: ['25/10/19',
#   '25/10/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  136: ['28/10/19',
#   '28/10/19',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  137: ['04/11/19',
#   '04/11/19',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  138: ['21/11/19',
#   '21/11/19',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  139: ['26/11/19',
#   '26/11/19',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  140: ['05/12/19',
#   '05/12/19',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  141: ['02/01/20',
#   '02/01/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  142: ['15/01/20',
#   '15/01/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  143: ['10/03/20',
#   '10/03/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  144: ['12/03/20',
#   '13/03/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  145: ['14/03/20',
#   '14/03/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  146: ['18/03/20',
#   '18/03/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  147: ['19/03/20',
#   '19/03/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  148: ['04/04/20',
#   '04/04/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  149: ['25/04/20',
#   '25/04/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  150: ['26/04/20',
#   '26/04/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  151: ['30/04/20',
#   '02/05/20',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  152: ['06/05/20',
#   '06/05/20',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  153: ['12/05/20',
#   '14/05/20',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  154: ['18/05/20',
#   '19/05/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  155: ['22/05/20',
#   '22/05/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  156: ['29/05/20',
#   '29/05/20',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  157: ['01/06/20',
#   '02/06/20',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  158: ['09/06/20',
#   '09/06/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  159: ['12/06/20',
#   '12/06/20',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  160: ['25/06/20',
#   '25/06/20',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  161: ['26/06/20',
#   '26/06/20',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  162: ['11/07/20',
#   '11/07/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  163: ['13/07/20',
#   '14/07/20',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  164: ['17/07/20',
#   '17/07/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  165: ['20/07/20',
#   '20/07/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  166: ['21/07/20',
#   '24/07/20',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  167: ['28/07/20',
#   '28/07/20',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  168: ['29/07/20',
#   '29/07/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  169: ['07/08/20',
#   '07/08/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  170: ['10/08/20',
#   '10/08/20',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  171: ['12/08/20',
#   '14/08/20',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  172: ['31/08/20',
#   '31/08/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  173: ['03/09/20',
#   '03/09/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  174: ['01/10/20',
#   '01/10/20',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  175: ['06/10/20',
#   '06/10/20',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  176: ['09/11/20',
#   '09/11/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  177: ['16/12/20',
#   '16/12/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  178: ['19/02/21',
#   '19/02/21',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  179: ['13/03/21',
#   '17/03/21',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  180: ['23/03/21',
#   '23/03/21',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  181: ['26/03/21',
#   '26/03/21',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  182: ['29/03/21',
#   '29/03/21',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  183: ['17/05/21',
#   '17/05/21',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  184: ['20/05/21',
#   '21/05/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  185: ['26/05/21',
#   '28/05/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  186: ['28/06/21',
#   '28/06/21',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  187: ['12/07/21',
#   '16/07/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  188: ['21/07/21',
#   '23/07/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  189: ['26/07/21',
#   '27/07/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  190: ['28/07/21',
#   '28/07/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  191: ['09/08/21',
#   '11/08/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  192: ['16/08/21',
#   '16/08/21',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  193: ['17/08/21',
#   '17/08/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  194: ['18/08/21',
#   '18/08/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  195: ['19/08/21',
#   '19/08/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  196: ['20/08/21',
#   '20/08/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  197: ['23/08/21',
#   '24/08/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  198: ['26/08/21',
#   '26/08/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  199: ['27/08/21',
#   '27/08/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  200: ['06/09/21',
#   '06/09/21',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  201: ['08/09/21',
#   '09/09/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  202: ['13/09/21',
#   '13/09/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  203: ['14/09/21',
#   '14/09/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  204: ['15/09/21',
#   '15/09/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  205: ['20/09/21',
#   '20/09/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  206: ['21/09/21',
#   '22/09/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  207: ['27/09/21',
#   '29/09/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media']}

# %%
  # transpor db para voltar ao formato convencional    
db = pd.DataFrame(db).transpose()    
new_col = list((inter_filter.columns).insert(1, 'f'))
new_col[0] = 'b'

# montar um DataFrame com os suportes de cada padrão encontrado em db
db = db.rename(columns={old:new for old, new in zip(db.columns, new_col)})
db_uniques = db.drop(columns=['b', 'f'])

supports = db.groupby(db_uniques.columns.tolist(),as_index=False).size()
print(supports)
supports['frequencia'] = (supports['size'] / db.shape[0]).round(3)


##########################################################################
################### gravar a duração de cada padrão ######################

# conversores de variável temporal
to_datetime = lambda date: datetime.datetime.strptime(date, '%d/%m/%y') # data_string em datetime
to_days     = lambda days_datetime: days_datetime.days                  # datetime em dias_int

# conversões auxiliares das colunas temporais
b_datetime = db['b'].apply(to_datetime)
f_datetime = db['f'].apply(to_datetime)

# calcula a duração de cada padrão e grava em db
duration = (f_datetime - b_datetime).apply(to_days) + 1
db['duration'] = duration

# padrões únicos detectados em db
aux = db.iloc[:, 2:-1]
uniques = aux.drop_duplicates()

# variáveis axiliares para uso posterior
first_day  = b_datetime.iloc[0]
last_day   = f_datetime.iloc[-1]
time_range = (last_day - first_day).days # // 12


###########################################################################
############################ LINHA TEMPORAL ###############################
# conversor datetime para string
to_strftime = lambda date: date.strftime('%d/%m/%y')

# linha temporal de db (taxa de amostragem = 1 dia)
date_line = np.linspace(first_day.value, last_day.value, num=time_range)
date_line = pd.to_datetime(date_line)
date_line = date_line.to_pydatetime()
date_line = pd.Series(date_line).apply(to_strftime)
###########################################################################
###########################################################################
#-------------------------------------------------------------------------#
###########################################################################
######################### METADADOS DO GRÁFICO ############################
data   = {} # armazenar [padrão, início, duração, cor]
colors = {} # armazenar uma cor por padrão detectado

# gerar e gravar em COLORS uma cor aleatória por padrão detectado 
for row in uniques.values:
    colors[str(row)] = np.random.random(3)
    
# gravar em DATA os demais metadados 
for i, row in enumerate(db.values):

    b = row[0]                                      # data inicial
    b_encoded  = to_datetime(b).timetuple().tm_yday # convertida em dia do ano
    zero_point = first_day.timetuple().tm_yday      # marcador de referência (origem temporal)

    
    pattern = str(row[2:-1])         # padrão em string
    left    = b_encoded - zero_point # ponto inicial no gráfico
    width   = row[-1]                # largura da barra no gráfico (duração do padrão)
    color   = colors[pattern]        # cor da barra no gráfico
    
    # gravação
    data[i] = {'pattern': pattern,
               'left': left,
               'width': width,
               'color': color}
###########################################################################
###########################################################################
#-------------------------------------------------------------------------#
###########################################################################
################################# PLOT ####################################

# XTICKLABELS (RAW)
x = np.arange(date_line.shape[0])
last_event = 0 # var auxiliar para editar x

# ------------------------------------- #
fig, ax = plt.subplots(figsize=(10, 5))

for i, key in enumerate(data):
    
    # recupere os metadados gravados em DATA
    y = data[key]['pattern']
    width = data[key]['width']
    left = data[key]['left']
    color = data[key]['color']
    
    # horizontal bar plot
    ax.barh(y, width, height=0.5, left=left, color='black', linewidth=10)
    
    ########## edição de XTICKLABELS ###############
    if width > 1:                         # evento
        x[left+1: left+width] = '-1'      
    
    if (left - last_event > 1) & (i > 1): # não evento
        x[last_event+1: left] = '-1'      
    
    last_event = left+width               # update 


# recuperar tick labels
xticks       = x
xtickslabels = date_line.values

yticks       = np.arange(uniques.shape[0])
ytickslabels = np.arange(uniques.shape[0])

# plotar
# ax.set_yticks(np.arange(uniques.shape[0]))

ax.set_xticks(xticks)
ax.set_xticklabels(xtickslabels, rotation=90)
ax.tick_params(axis='x', labelsize=8)
plt.xlim(0, time_range+1)

ax.set_yticks(yticks)
ax.set_yticklabels(ytickslabels)

plt.xlabel("Dia")
plt.ylabel("Padrão")
plt.grid(which='major', axis='x', linestyle=(0, (5, 10)), linewidth=.5)
plt.title("Incidência de padrões")
plt.savefig(plot_path)
plt.show()
# Out:
#         MP25       MP10         CO        SO2        NO2         O3  \
# 0  inf_media  inf_media  inf_media  inf_media  inf_media  sup_media
# 1  inf_media  sup_media  inf_media  inf_media  inf_media  inf_media
# 2  sup_media  inf_media  inf_media  inf_media  inf_media  inf_media
# 3  sup_media  inf_media  inf_media  inf_media  inf_media  sup_media
# 4  sup_media  sup_media  inf_media  inf_media  inf_media  inf_media
# 5  sup_media  sup_media  inf_media  inf_media  inf_media  sup_media
#
#   internacao  size
# 0  sup_media    33
# 1  sup_media     3
# 2  sup_media    61
# 3  sup_media    10
# 4  sup_media    80
# 5  sup_media    21

# %%
supports
# Out:
#         MP25       MP10         CO        SO2        NO2         O3  \
# 0  inf_media  inf_media  inf_media  inf_media  inf_media  sup_media
# 1  inf_media  sup_media  inf_media  inf_media  inf_media  inf_media
# 2  sup_media  inf_media  inf_media  inf_media  inf_media  inf_media
# 3  sup_media  inf_media  inf_media  inf_media  inf_media  sup_media
# 4  sup_media  sup_media  inf_media  inf_media  inf_media  inf_media
# 5  sup_media  sup_media  inf_media  inf_media  inf_media  sup_media
#
#   internacao  size  frequencia
# 0  sup_media    33       0.159
# 1  sup_media     3       0.014
# 2  sup_media    61       0.293
# 3  sup_media    10       0.048
# 4  sup_media    80       0.385
# 5  sup_media    21       0.101
