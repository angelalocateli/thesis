# %%
# SETUP

import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt

db_path = 'campinas.csv'
plot_path = 'plt.jpg'
# db_path = input("Caminho para .csv:\n -> ")
# plot_path = input("\n\n plot output path:\n -> ")

df = pd.read_csv(db_path, sep=';')

#filtrando internações SUP_MEDIA
#consequente = df[(df.internacao=='inf_media') | (df.internacao=='sup_media') ]
consequente = df[df['internacao'] != 'inf_media'].dropna()
consequente = consequente.reset_index(drop=True)
consequente
# Out:
#            Data       MP10       MP25        NO2         CO        SO2  \
# 0    04/01/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 1    11/01/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 2    20/01/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 3    21/01/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 4    23/01/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# ..          ...        ...        ...        ...        ...        ...
# 744  06/09/2021  inf_media  inf_media  inf_media  inf_media  inf_media
# 745  08/09/2021  sup_media  inf_media  inf_media  inf_media  inf_media
# 746  09/09/2021  sup_media  inf_media  inf_media  inf_media  inf_media
# 747  22/09/2021  sup_media  inf_media  inf_media  inf_media  inf_media
# 748  27/09/2021  inf_media  sup_media  inf_media  inf_media  inf_media
#
#             O3 internacao
# 0    inf_media  sup_media
# 1    inf_media  sup_media
# 2    inf_media  sup_media
# 3    inf_media  sup_media
# 4    inf_media  sup_media
# ..         ...        ...
# 744  sup_media  sup_media
# 745  sup_media  sup_media
# 746  sup_media  sup_media
# 747  inf_media  sup_media
# 748  inf_media  sup_media
#
# [749 rows x 8 columns]

# %%
#filtrando poluentes SUP_MEDIA
inter_filter = consequente[(consequente.MP25=='sup_media') | (consequente.MP10=='sup_media') | (consequente.NO2=='sup_media') | (consequente.O3=='sup_media')]
inter_filter = inter_filter.reset_index(drop=True)
inter_filter
# Out:
#            Data       MP10       MP25        NO2         CO        SO2  \
# 0    16/02/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 1    17/02/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 2    20/02/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 3    21/02/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# 4    13/03/2017  inf_media  inf_media  inf_media  inf_media  inf_media
# ..          ...        ...        ...        ...        ...        ...
# 226  06/09/2021  inf_media  inf_media  inf_media  inf_media  inf_media
# 227  08/09/2021  sup_media  inf_media  inf_media  inf_media  inf_media
# 228  09/09/2021  sup_media  inf_media  inf_media  inf_media  inf_media
# 229  22/09/2021  sup_media  inf_media  inf_media  inf_media  inf_media
# 230  27/09/2021  inf_media  sup_media  inf_media  inf_media  inf_media
#
#             O3 internacao
# 0    sup_media  sup_media
# 1    sup_media  sup_media
# 2    sup_media  sup_media
# 3    sup_media  sup_media
# 4    sup_media  sup_media
# ..         ...        ...
# 226  sup_media  sup_media
# 227  sup_media  sup_media
# 228  sup_media  sup_media
# 229  inf_media  sup_media
# 230  inf_media  sup_media
#
# [231 rows x 8 columns]

# %%
# resumo
inter_filter.describe()
# Out:
#               Data       MP10       MP25        NO2         CO        SO2  \
# count          231        231        231        231        231        231
# unique         231          2          2          1          1          1
# top     16/02/2017  inf_media  sup_media  inf_media  inf_media  inf_media
# freq             1        199        184        231        231        231
#
#                O3 internacao
# count         231        231
# unique          2          1
# top     inf_media  sup_media
# freq          175        231

# %%
# DETECÇÃO DE PADRÕES

db = {}  # irá armazenar os padrões em dias consecutivos
code = 0 # chave de acesso ao db
for index, row_i in inter_filter.iterrows():
    if index == 0:
        row_0 = row_i

    # salve os tempos iniciais e finais (b e f) do padrão
    b = datetime.datetime.strptime(row_0['Data'], '%d/%m/%Y')    
    f = datetime.datetime.strptime(row_i['Data'], '%d/%m/%Y')
    diff = (f - b).days
    
    # padrão que não se repete em dias consecutivos
    pattern = [
        datetime.datetime.strftime(f, '%d/%m/%y'),
        datetime.datetime.strftime(f, '%d/%m/%y'),
        *row_i[1:]
    ]    
    
    # padrão que se repete em dias consecutivos
    if (row_i[1:].equals(row_0[1:])) and diff <= 1:
                    
        pattern = [
            datetime.datetime.strftime(b, '%d/%m/%y'),
            datetime.datetime.strftime(f, '%d/%m/%y'),
            *row_i[1:]
        ]
    else:
        code += 1
        
    # guarde o padrão no novo db
    if db.get(code, 0):
        db[code][1] = pattern[1] # apenas altera a data f caso já exista
    else:
        db[code] = pattern
    
    # passo
    row_0 = row_i

# %%
# lista os padrões com os tempos iniciais e finais (b e f)
db
# Out:
# {0: ['16/02/17',
#   '17/02/17',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  1: ['20/02/17',
#   '21/02/17',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  2: ['13/03/17',
#   '13/03/17',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  3: ['21/03/17',
#   '21/03/17',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  4: ['24/03/17',
#   '24/03/17',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  5: ['05/04/17',
#   '06/04/17',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  6: ['11/04/17',
#   '11/04/17',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  7: ['13/05/17',
#   '13/05/17',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  8: ['26/05/17',
#   '26/05/17',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  9: ['28/05/17',
#   '28/05/17',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  10: ['30/05/17',
#   '30/05/17',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  11: ['12/06/17',
#   '13/06/17',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  12: ['31/07/17',
#   '31/07/17',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  13: ['07/08/17',
#   '07/08/17',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  14: ['08/08/17',
#   '09/08/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  15: ['11/08/17',
#   '11/08/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  16: ['14/08/17',
#   '15/08/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  17: ['27/08/17',
#   '27/08/17',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  18: ['28/08/17',
#   '30/08/17',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  19: ['04/09/17',
#   '04/09/17',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  20: ['06/09/17',
#   '06/09/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  21: ['11/09/17',
#   '11/09/17',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  22: ['13/09/17',
#   '14/09/17',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  23: ['15/09/17',
#   '15/09/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  24: ['18/09/17',
#   '20/09/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  25: ['28/09/17',
#   '28/09/17',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  26: ['10/10/17',
#   '10/10/17',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  27: ['29/11/17',
#   '29/11/17',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  28: ['22/01/18',
#   '23/01/18',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  29: ['25/01/18',
#   '25/01/18',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  30: ['08/02/18',
#   '08/02/18',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  31: ['28/03/18',
#   '28/03/18',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  32: ['05/04/18',
#   '06/04/18',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  33: ['14/04/18',
#   '14/04/18',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  34: ['20/04/18',
#   '21/04/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  35: ['26/04/18',
#   '26/04/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  36: ['01/05/18',
#   '02/05/18',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  37: ['04/05/18',
#   '04/05/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  38: ['05/05/18',
#   '05/05/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  39: ['06/05/18',
#   '06/05/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  40: ['11/05/18',
#   '11/05/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  41: ['15/05/18',
#   '17/05/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  42: ['22/05/18',
#   '22/05/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  43: ['23/05/18',
#   '23/05/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  44: ['03/06/18',
#   '05/06/18',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  45: ['06/06/18',
#   '06/06/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  46: ['20/06/18',
#   '20/06/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  47: ['22/06/18',
#   '25/06/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  48: ['28/06/18',
#   '30/06/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  49: ['02/07/18',
#   '07/07/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  50: ['10/07/18',
#   '10/07/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  51: ['16/07/18',
#   '16/07/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  52: ['18/07/18',
#   '18/07/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  53: ['23/07/18',
#   '24/07/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  54: ['15/08/18',
#   '16/08/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  55: ['21/08/18',
#   '22/08/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  56: ['23/08/18',
#   '23/08/18',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  57: ['24/09/18',
#   '24/09/18',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  58: ['25/09/18',
#   '25/09/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  59: ['26/09/18',
#   '27/09/18',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  60: ['27/03/19',
#   '27/03/19',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  61: ['01/04/19',
#   '01/04/19',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  62: ['03/04/19',
#   '03/04/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  63: ['04/04/19',
#   '04/04/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  64: ['05/04/19',
#   '05/04/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  65: ['27/04/19',
#   '27/04/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  66: ['30/04/19',
#   '30/04/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  67: ['02/05/19',
#   '04/05/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  68: ['07/05/19',
#   '07/05/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  69: ['10/05/19',
#   '10/05/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  70: ['14/05/19',
#   '15/05/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  71: ['20/05/19',
#   '23/05/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  72: ['25/05/19',
#   '25/05/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  73: ['27/05/19',
#   '29/05/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  74: ['07/06/19',
#   '08/06/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  75: ['11/06/19',
#   '21/06/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  76: ['23/06/19',
#   '23/06/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  77: ['25/06/19',
#   '26/06/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  78: ['27/06/19',
#   '27/06/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  79: ['28/06/19',
#   '28/06/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  80: ['30/06/19',
#   '01/07/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  81: ['03/07/19',
#   '03/07/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  82: ['05/07/19',
#   '05/07/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  83: ['10/07/19',
#   '10/07/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  84: ['15/07/19',
#   '16/07/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  85: ['23/07/19',
#   '24/07/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  86: ['29/07/19',
#   '29/07/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  87: ['01/08/19',
#   '02/08/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  88: ['08/08/19',
#   '08/08/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  89: ['12/08/19',
#   '14/08/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  90: ['16/08/19',
#   '16/08/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  91: ['19/08/19',
#   '19/08/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  92: ['01/09/19',
#   '01/09/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  93: ['04/09/19',
#   '04/09/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  94: ['09/09/19',
#   '11/09/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  95: ['17/09/19',
#   '20/09/19',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  96: ['01/10/19',
#   '01/10/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  97: ['03/10/19',
#   '03/10/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  98: ['04/10/19',
#   '04/10/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  99: ['21/10/19',
#   '22/10/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  100: ['31/10/19',
#   '31/10/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  101: ['04/11/19',
#   '04/11/19',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  102: ['27/01/20',
#   '27/01/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  103: ['06/03/20',
#   '06/03/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  104: ['11/03/20',
#   '11/03/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  105: ['14/03/20',
#   '14/03/20',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  106: ['07/04/20',
#   '07/04/20',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  107: ['14/05/20',
#   '14/05/20',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  108: ['19/05/20',
#   '19/05/20',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  109: ['21/05/20',
#   '21/05/20',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  110: ['14/08/20',
#   '14/08/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  111: ['08/09/20',
#   '08/09/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  112: ['10/09/20',
#   '10/09/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  113: ['14/09/20',
#   '14/09/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  114: ['17/09/20',
#   '17/09/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  115: ['29/09/20',
#   '29/09/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  116: ['01/10/20',
#   '02/10/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  117: ['14/10/20',
#   '14/10/20',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  118: ['26/10/20',
#   '26/10/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  119: ['29/10/20',
#   '29/10/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  120: ['11/11/20',
#   '11/11/20',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  121: ['24/02/21',
#   '24/02/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  122: ['09/03/21',
#   '09/03/21',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  123: ['22/03/21',
#   '22/03/21',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  124: ['24/03/21',
#   '24/03/21',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  125: ['27/03/21',
#   '27/03/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  126: ['05/05/21',
#   '06/05/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  127: ['11/05/21',
#   '13/05/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  128: ['20/05/21',
#   '22/05/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  129: ['26/05/21',
#   '28/05/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  130: ['03/06/21',
#   '04/06/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  131: ['03/07/21',
#   '03/07/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  132: ['12/07/21',
#   '16/07/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  133: ['20/07/21',
#   '22/07/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  134: ['26/07/21',
#   '26/07/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  135: ['10/08/21',
#   '10/08/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  136: ['11/08/21',
#   '11/08/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  137: ['12/08/21',
#   '12/08/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  138: ['15/08/21',
#   '15/08/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  139: ['17/08/21',
#   '19/08/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  140: ['22/08/21',
#   '23/08/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  141: ['24/08/21',
#   '25/08/21',
#   'sup_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  142: ['06/09/21',
#   '06/09/21',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  143: ['08/09/21',
#   '09/09/21',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media',
#   'sup_media'],
#  144: ['22/09/21',
#   '22/09/21',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media'],
#  145: ['27/09/21',
#   '27/09/21',
#   'inf_media',
#   'sup_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'inf_media',
#   'sup_media']}

# %%
  
# transpor db para voltar ao formato convencional    
db = pd.DataFrame(db).transpose()    
new_col = list((inter_filter.columns).insert(1, 'f'))
new_col[0] = 'b'

# montar um DataFrame com os suportes de cada padrão encontrado em db
db = db.rename(columns={old:new for old, new in zip(db.columns, new_col)})
db_uniques = db.drop(columns=['b', 'f'])

supports = db.groupby(db_uniques.columns.tolist(),as_index=False).size()
print(supports)
supports['frequencia'] = (supports['size'] / db.shape[0]).round(3)


##########################################################################
################### gravar a duração de cada padrão ######################

# conversores de variável temporal
to_datetime = lambda date: datetime.datetime.strptime(date, '%d/%m/%y') # data_string em datetime
to_days     = lambda days_datetime: days_datetime.days                  # datetime em dias_int

# conversões auxiliares das colunas temporais
b_datetime = db['b'].apply(to_datetime)
f_datetime = db['f'].apply(to_datetime)

# calcula a duração de cada padrão e grava em db
duration = (f_datetime - b_datetime).apply(to_days) + 1
db['duration'] = duration

# padrões únicos detectados em db
aux = db.iloc[:, 2:-1]
uniques = aux.drop_duplicates()

# variáveis axiliares para uso posterior
first_day  = b_datetime.iloc[0]
last_day   = f_datetime.iloc[-1]
time_range = (last_day - first_day).days # // 12


###########################################################################
############################ LINHA TEMPORAL ###############################
# conversor datetime para string
to_strftime = lambda date: date.strftime('%d/%m/%y')

# linha temporal de db (taxa de amostragem = 1 dia)
date_line = np.linspace(first_day.value, last_day.value, num=time_range)
date_line = pd.to_datetime(date_line)
date_line = date_line.to_pydatetime()
date_line = pd.Series(date_line).apply(to_strftime)
###########################################################################
###########################################################################
#-------------------------------------------------------------------------#
###########################################################################
######################### METADADOS DO GRÁFICO ############################
data   = {} # armazenar [padrão, início, duração, cor]
colors = {} # armazenar uma cor por padrão detectado

# gerar e gravar em COLORS uma cor aleatória por padrão detectado 
for row in uniques.values:
    colors[str(row)] = np.random.random(3)
    
# gravar em DATA os demais metadados 
for i, row in enumerate(db.values):

    b = row[0]                                      # data inicial
    b_encoded  = to_datetime(b).timetuple().tm_yday # convertida em dia do ano
    zero_point = first_day.timetuple().tm_yday      # marcador de referência (origem temporal)

    
    pattern = str(row[2:-1])         # padrão em string
    left    = b_encoded - zero_point # ponto inicial no gráfico
    width   = row[-1]                # largura da barra no gráfico (duração do padrão)
    color   = colors[pattern]        # cor da barra no gráfico
    
    # gravação
    data[i] = {'pattern': pattern,
               'left': left,
               'width': width,
               'color': color}
###########################################################################
###########################################################################
#-------------------------------------------------------------------------#
###########################################################################
################################# PLOT ####################################

# XTICKLABELS (RAW)
x = np.arange(date_line.shape[0])
last_event = 0 # var auxiliar para editar x

# ------------------------------------- #
fig, ax = plt.subplots(figsize=(10, 5))

for i, key in enumerate(data):
    
    # recupere os metadados gravados em DATA
    y = data[key]['pattern']
    width = data[key]['width']
    left = data[key]['left']
    color = data[key]['color']
    
    # horizontal bar plot
    ax.barh(y, width, height=0.5, left=left, color='black', linewidth=10)
    
    ########## edição de XTICKLABELS ###############
    if width > 1:                         # evento
        x[left+1: left+width] = '-1'      
    
    if (left - last_event > 1) & (i > 1): # não evento
        x[last_event+1: left] = '-1'      
    
    last_event = left+width               # update 


# recuperar tick labels
xticks       = x
xtickslabels = date_line.values

yticks       = np.arange(uniques.shape[0])
ytickslabels = np.arange(uniques.shape[0])

# plotar
# ax.set_yticks(np.arange(uniques.shape[0]))

ax.set_xticks(xticks)
ax.set_xticklabels(xtickslabels, rotation=90)
ax.tick_params(axis='x', labelsize=8)
plt.xlim(0, time_range+1)

ax.set_yticks(yticks)
ax.set_yticklabels(ytickslabels)

plt.xlabel("Dia")
plt.ylabel("Padrão")
plt.grid(which='major', axis='x', linestyle=(0, (5, 10)), linewidth=.5)
plt.title("Incidência de padrões")
plt.savefig(plot_path)
plt.show()
# Out:
#         MP10       MP25        NO2         CO        SO2         O3  \
# 0  inf_media  inf_media  inf_media  inf_media  inf_media  sup_media
# 1  inf_media  sup_media  inf_media  inf_media  inf_media  inf_media
# 2  inf_media  sup_media  inf_media  inf_media  inf_media  sup_media
# 3  sup_media  inf_media  inf_media  inf_media  inf_media  inf_media
# 4  sup_media  inf_media  inf_media  inf_media  inf_media  sup_media
# 5  sup_media  sup_media  inf_media  inf_media  inf_media  inf_media
# 6  sup_media  sup_media  inf_media  inf_media  inf_media  sup_media
#
#   internacao  size
# 0  sup_media    30
# 1  sup_media    88
# 2  sup_media     7
# 3  sup_media     4
# 4  sup_media     4
# 5  sup_media     9
# 6  sup_media     4

# %%
supports
# Out:
#         MP10       MP25        NO2         CO        SO2         O3  \
# 0  inf_media  inf_media  inf_media  inf_media  inf_media  sup_media
# 1  inf_media  sup_media  inf_media  inf_media  inf_media  inf_media
# 2  inf_media  sup_media  inf_media  inf_media  inf_media  sup_media
# 3  sup_media  inf_media  inf_media  inf_media  inf_media  inf_media
# 4  sup_media  inf_media  inf_media  inf_media  inf_media  sup_media
# 5  sup_media  sup_media  inf_media  inf_media  inf_media  inf_media
# 6  sup_media  sup_media  inf_media  inf_media  inf_media  sup_media
#
#   internacao  size  frequencia
# 0  sup_media    30       0.205
# 1  sup_media    88       0.603
# 2  sup_media     7       0.048
# 3  sup_media     4       0.027
# 4  sup_media     4       0.027
# 5  sup_media     9       0.062
# 6  sup_media     4       0.027
